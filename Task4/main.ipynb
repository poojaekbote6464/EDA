# %%
import pandas as pd

df = pd.read_excel('D:\Innomatics\Task4\data.xlsx')
print(df.head())
print('\n')
print("Shape: ", df.shape)
print("Data description:")
formatted_desc = df.describe().applymap(lambda x: format(x, 'f'))
print(formatted_desc)
# Out:
#        ID   Salary        DOJ                  DOL               Designation  \
# 0  203097   420000 2012-06-01              present   senior quality engineer
# 1  579905   500000 2013-09-01              present         assistant manager
# 2  810601   325000 2014-06-01              present          systems engineer
# 3  267447  1100000 2011-07-01              present  senior software engineer
# 4  343523   200000 2014-03-01  2015-03-01 00:00:00                       get
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  Bangalore      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     Indore      m 1989-10-04          85.4                            cbse
# 2    Chennai      f 1992-08-03          85.0                            cbse
# 3    Gurgaon      m 1989-12-05          85.6                            cbse
# 4    Manesar      m 1991-02-27          78.0                            cbse
#
# ...

# %%
df.set_index("ID" ,inplace=True)
df.head()
# Out:
#          Salary        DOJ                  DOL               Designation  \
# ID
# 203097   420000 2012-06-01              present   senior quality engineer
# 579905   500000 2013-09-01              present         assistant manager
# 810601   325000 2014-06-01              present          systems engineer
# 267447  1100000 2011-07-01              present  senior software engineer
# 343523   200000 2014-03-01  2015-03-01 00:00:00                       get
#
#           JobCity Gender        DOB  10percentage  \
# ID
# 203097  Bangalore      f 1990-02-19          84.3
# 579905     Indore      m 1989-10-04          85.4
# 810601    Chennai      f 1992-08-03          85.0
# 267447    Gurgaon      m 1989-12-05          85.6
# 343523    Manesar      m 1991-02-27          78.0
#
#                                10board  12graduation  ...  ComputerScience  \
# ID                                                    ...
# ...

# %%
missing_values = df["Salary"].isnull().sum()

if missing_values:
    print("Missing values are present.")
else:
    print("No missing values are present.")
# Out:
# No missing values are present.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.hist(df["Salary"], bins=20, edgecolor="black")
plt.xlabel("Salary")
plt.ylabel("Number of employees")
plt.title("Histogram of Salary")
plt.grid(axis="y")
plt.show()
plt.figure(figsize=(8, 6))
plt.boxplot(df['Salary'], vert=False)
plt.title('Box Plot of Salary')
plt.xlabel('Salary')
plt.show()
q1_S = df["Salary"].quantile(0.25)
q3_S = df["Salary"].quantile(0.75)
iqr_S = q3_S - q1_S

print(q1_S)
print(q3_S)
print(iqr_S)
# Out:
# 180000.0
# 370000.0
# 190000.0

# %% [markdown]
# The distribution appears to be somewhat right-skewed, with more employees clustered towards the lower salary range and fewer towards the higher salary range.
# The majority of employees seem to have salaries within a certain range, with a gradual decrease in the number of employees as salary increases.
# There might be some outliers towards the higher end of the salary range, indicated by the long tail in the histogram.

# %% [markdown]
# The box plot confirms the presence of outliers towards the higher end of the salary range, as indicated by data points lying beyond the upper whisker.
# The median salary (Q2) is represented by the line within the box, indicating the central tendency of the salary distribution.
# The box represents the interquartile range (IQR), which encompasses the middle 50% of the data.
# The whiskers extend to the minimum and maximum values within 1.5 times the IQR from the first and third quartiles, respectively.

# %% [markdown]
# he first quartile (Q1) represents the salary below which 25% of the data falls.
# The third quartile (Q3) represents the salary below which 75% of the data falls.
# The interquartile range (IQR), calculated as the difference between Q3 and Q1, provides a measure of the spread of the middle 50% of the data.
# A larger interquartile range indicates greater variability in salaries among employees.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_columns = ['Salary', '10percentage', '12percentage', 'collegeGPA', 'English', 'Logical', 'Quant', 
                     'Domain', 'ComputerProgramming', 'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg', 
                     'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness', 'agreeableness', 
                     'extraversion', 'nueroticism', 'openess_to_experience']

# Plot histograms for numerical columns
plt.figure(figsize=(20, 25))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(7, 3, i)
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'{col} Distribution')

plt.tight_layout()
plt.show()

# Plot box plots for numerical columns
plt.figure(figsize=(20, 15))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'{col} Boxplot')

plt.tight_layout()
plt.show()

categorical_columns = ['Designation', 'JobCity', 'Gender', 'Degree', 'Specialization', 'CollegeTier', 'CollegeState', 'GraduationYear']

# Plot countplots for categorical columns
plt.figure(figsize=(20, 25))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(4, 2, i)
    sns.countplot(data=df, x=col, palette='pastel')
    plt.title(f'{col} Countplot')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_193600\42211429.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='pastel')
# C:\Users\pooja\AppData\Local\Temp\ipykernel_193600\42211429.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='pastel')
# C:\Users\pooja\AppData\Local\Temp\ipykernel_193600\42211429.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='pastel')
# ...

# %% [markdown]
# These histograms provide a visual representation of the distribution of values for each numerical attribute.
# For example, the histogram for salary distribution helps understand the salary ranges within the dataset and the frequency of occurrence within each range.
# Similarly, histograms for academic percentages (10th, 12th, and college GPA) depict the distribution of academic performance among candidates.
# Histograms for personality traits (conscientiousness, agreeableness, etc.) showcase the distribution of these traits within the dataset, potentially revealing trends or patterns in candidate personalities.

# %%
chosen_columns = ['Salary', '10percentage', '12percentage', 
        'collegeGPA', 'English', 'Logical', 'Quant', 'Domain',
       'ComputerProgramming', 'ComputerScience', 'conscientiousness',
       'agreeableness', 'extraversion', 'nueroticism', 'openess_to_experience']

chosen_df = df[chosen_columns]
chosen_df.head()

plagiarized_matrix = chosen_df.corr()

plt.figure(figsize=(8, 8), dpi=100)
sns.heatmap(plagiarized_matrix)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# These selected columns likely represent key features or factors of interest for analysis.
# Attributes such as salary, academic performance, and personality traits are commonly studied in various domains, including HR analytics, education research, and psychological studies.

# %% [markdown]
# The heatmap provides a graphical representation of the correlation matrix, with colors indicating the strength and direction of correlations.
# Darker shades represent stronger correlations, while lighter shades represent weaker correlations or no correlation.
# Patterns in the heatmap can reveal clusters of attributes that are highly correlated, which can be valuable for feature selection, model building, and further analysis.

# %%
unique_designations = df['Designation'].unique()

average_salary_by_designation = df.groupby('Designation')['Salary'].mean()

sorted_average_salary = average_salary_by_designation.sort_values(ascending=False)

top_10_designations_highest_salary = sorted_average_salary.head(50)
print(top_10_designations_highest_salary)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_designations_highest_salary.index, y=top_10_designations_highest_salary.values, palette='viridis')
plt.title('Top 50 Designations with Highest Average Salary')
plt.xticks(rotation=45, ha='right')  
plt.xlabel('Designation')
plt.ylabel('Average Salary')
plt.show()
# Out:
# Designation
# junior manager                       1.300000e+06
# senior developer                     1.110000e+06
# data scientist                       8.966667e+05
# field engineer                       8.016667e+05
# asst. manager                        8.000000e+05
# software engineer trainee            7.816667e+05
# research scientist                   7.300000e+05
# branch manager                       7.125000e+05
# sales account manager                7.100000e+05
# technical lead                       6.690000e+05
# technology lead                      6.450000e+05
# automation engineer                  6.406667e+05
# technical analyst                    6.000000e+05
# sr. database engineer                6.000000e+05
# technology analyst                   5.691667e+05
# business technology analyst          5.650000e+05
# planning engineer                    5.525000e+05
# manager                              5.525000e+05
# ...

# %% [markdown]
# Understanding the unique designations within the dataset is essential for identifying different job roles or positions held by individuals.

# %% [markdown]
# By identifying the top 50 designations with the highest average salary, the code highlights high-paying positions within the dataset.
# Insight: This information is valuable for job seekers, employers, and HR professionals in identifying lucrative job opportunities and understanding the competitive landscape in terms of compensation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='10percentage', y='Salary', data=df)
plt.xlabel('10th Percentage')
plt.ylabel('Salary')
plt.title('Scatter Plot: Salary vs 10th Percentage')
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df['12percentage'], df['Salary'], alpha=0.5)
plt.title('Salary vs 12th Percentage')
plt.xlabel('12th Percentage')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df['collegeGPA'], df['Salary'], alpha=0.5)
plt.title('Salary vs College GPA')
plt.xlabel('College GPA')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot allows us to understand if there is any correlation between a candidate's performance in their 10th-grade exams and their salary.
# It helps in identifying any potential patterns or trends regarding salary levels based on 10th-grade performance.

# %% [markdown]
# By plotting salary against college GPA, we can examine the impact of academic performance during college on salary levels.
# It helps in assessing whether employers place significant importance on college grades when determining salary offers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(12, 8))
sns.swarmplot(x="Specialization", y="Salary", data=df)
plt.xticks(rotation=45, ha='right')
plt.title('Swarm Plot of Salary vs Specialization')
plt.xlabel('Specialization')
plt.ylabel('Salary')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pooja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning: 92.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\pooja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning: 95.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\pooja\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3399: UserWarning: 94.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df["YearsOfExperience"] = (df["DOJ"] - df["DOB"]) // pd.Timedelta(days=365)

# Create scatter plots
numerical_variables = ["English", "Logical", "Quant", "collegeGPA", "YearsOfExperience"]
for var in numerical_variables:
    plt.figure(figsize=(8, 6))
    plt.scatter(df["Salary"], df[var])
    plt.xlabel("Salary")
    plt.ylabel(var)
    plt.title(f"Salary vs. {var}")
    plt.grid(True)
    plt.show()

# %% [markdown]
# This visualization allows us to observe the salary ranges associated with different specializations within the dataset.
# It provides insights into the variability of salaries across different fields of study or expertise.
# Analyzing the swarm plot helps in identifying any notable differences or patterns in salary distributions among various specializations.

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y="Salary", x="CollegeTier", data=df)
plt.title("CollegeTier VS Salary")
plt.show()

# %%
df = pd.read_excel('data.xlsx')
job_roles =['Programmer Analyst', 'Software Engineer', 'Hardware Engineer' , 'Associate Engineer' ]
job_roles = [s.lower() for s in job_roles]
# print(job_roles)
designation_df = df['Designation']

average_salary_by_designation = {}

for designation in job_roles:
    designation_df = df[df['Designation'] == designation]
    average_salary = designation_df['Salary'].mean()
    average_salary_by_designation[designation] = average_salary

for designation, average_salary in average_salary_by_designation.items():
    print(f"Average salary for {designation}: {average_salary}")
# Out:
# Average salary for programmer analyst: 339784.1726618705
# Average salary for software engineer: 341215.2133580705
# Average salary for hardware engineer: 281250.0
# Average salary for associate engineer: 290000.0

# %%
specialization_df = df['Specialization'].unique()
print(specialization_df)
# Out:
# ['computer engineering' 'electronics and communication engineering'
#  'information technology' 'computer science & engineering'
#  'mechanical engineering' 'electronics and electrical engineering'
#  'electronics & telecommunications'
#  'instrumentation and control engineering' 'computer application'
#  'electronics and computer engineering' 'electrical engineering'
#  'applied electronics and instrumentation'
#  'electronics & instrumentation eng' 'information science engineering'
#  'civil engineering' 'mechanical and automation'
#  'industrial & production engineering'
#  'control and instrumentation engineering' 'metallurgical engineering'
#  'electronics and instrumentation engineering' 'electronics engineering'
#  'ceramic engineering' 'chemical engineering' 'aeronautical engineering'
#  'other' 'biotechnology' 'embedded systems technology'
#  'electrical and power engineering' 'computer science and technology'
# ...

# %%
specializations = ['computer engineering', 'electronics and communication engineering',
                   'information technology', 'computer science & engineering',
                   'mechanical engineering', 'electronics and electrical engineering',
                   'electronics & telecommunications', 'instrumentation and control engineering',
                   'computer application', 'electronics and computer engineering',
                   'electrical engineering', 'applied electronics and instrumentation',
                   'electronics & instrumentation eng', 'information science engineering',
                   'civil engineering', 'mechanical and automation',
                   'industrial & production engineering', 'control and instrumentation engineering',
                   'metallurgical engineering', 'electronics and instrumentation engineering',
                   'electronics engineering', 'ceramic engineering', 'chemical engineering',
                   'aeronautical engineering', 'other', 'biotechnology',
                   'embedded systems technology', 'electrical and power engineering',
                   'computer science and technology', 'mechatronics',
                   'automobile/automotive engineering', 'polymer technology',
                   'mechanical & production engineering', 'power systems and automation',
                   'instrumentation engineering', 'telecommunication engineering',
                   'industrial & management engineering', 'industrial engineering',
                   'computer and communication engineering', 'information & communication technology',
                   'information science', 'internal combustion engine', 'computer networking',
                   'biomedical engineering', 'electronics', 'computer science']


df['Specialization'] = df['Specialization'].str.lower()

specialization_counts = {}
for specialization in specializations:
    count = df[df['Specialization'] == specialization].shape[0]
    specialization_counts[specialization] = count
specialization_df = pd.DataFrame.from_dict(specialization_counts, orient='index', columns=['Count'])
specialization_df = specialization_df.sort_values(by='Count', ascending=False)
print(specialization_df)


import pandas as pd

specialization_categories = {
    'computer engineering': 'CS',
    'electronics and communication engineering': 'EC',
    'information technology': 'CS',
    'computer science & engineering': 'CS',
    'mechanical engineering': 'ME',
    'electronics and electrical engineering': 'EC',
    'electronics & telecommunications': 'EC',
    'instrumentation and control engineering': 'EC',
    'computer application': 'CS',
    'electronics and computer engineering': 'EC',
    'electrical engineering': 'EC',
    'applied electronics and instrumentation': 'EC',
    'electronics & instrumentation eng': 'EC',
    'information science engineering': 'CS',
    'civil engineering': 'CIV',
    'mechanical and automation': 'ME',
    'industrial & production engineering': 'ME',
    'control and instrumentation engineering': 'EC',
    'metallurgical engineering': 'ME',
    'electronics and instrumentation engineering': 'EC',
    'electronics engineering': 'EC',
    'ceramic engineering': 'CIV',  
    'chemical engineering': 'CIV',  
    'aeronautical engineering': 'ME',
    'other': 'Other',
    'biotechnology': 'Other',
    'embedded systems technology': 'EC',
    'electrical and power engineering': 'EC',
    'computer science and technology': 'CS',
    'mechatronics': 'ME',
    'automobile/automotive engineering': 'ME',
    'polymer technology': 'Other',
    'mechanical & production engineering': 'ME',
    'power systems and automation': 'EC',
    'instrumentation engineering': 'EC',
    'telecommunication engineering': 'EC',
    'industrial & management engineering': 'ME',
    'industrial engineering': 'ME',
    'computer and communication engineering': 'EC',
    'information & communication technology': 'CS',
    'information science': 'CS',
    'internal combustion engine': 'ME',
    'computer networking': 'CS',
    'biomedical engineering': 'Other',
    'electronics': 'EC',
    'computer science': 'CS'  
}

df['Specialization'] = df['Specialization'].str.lower()
df['Category'] = df['Specialization'].map(specialization_categories)
# Out:
#                                              Count
# electronics and communication engineering      880
# computer science & engineering                 744
# information technology                         660
# computer engineering                           600
# computer application                           244
# mechanical engineering                         201
# electronics and electrical engineering         196
# electronics & telecommunications               121
# electrical engineering                          82
# electronics & instrumentation eng               32
# civil engineering                               29
# electronics and instrumentation engineering     27
# information science engineering                 27
# instrumentation and control engineering         20
# electronics engineering                         19
# biotechnology                                   15
# other                                           13
# ...

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Gender'], df['Specialization'])

chi2_stat, p_val, _, _ = chi2_contingency(contingency_table)
print("Chi-Squared Statistic:", chi2_stat)
print("P-value:", p_val)

alpha = 0.05
if p_val < alpha:
    print("There is a significant relationship between gender and specialization.")
else:
    print("There is no significant relationship between gender and specialization.")
contingency_table = pd.crosstab(df['Gender'], df['Specialization'])


contingency_table.plot(kind='bar', stacked=True, figsize=(10, 6))

plt.title('Specialization Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0) 
plt.legend().remove()  
# plt.legend(title='Specialization')
plt.tight_layout()
plt.show()

contingency_table.plot(kind='bar', figsize=(10, 6))
plt.title('Specialization Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend().remove()   
# plt.legend(title='Specialization')
plt.tight_layout()
plt.show()
# Out:
# Chi-Squared Statistic: 104.46891913608455
# P-value: 1.2453868176976918e-06
# There is a significant relationship between gender and specialization.
